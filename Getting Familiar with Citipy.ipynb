# %%
#import random module
import random

# %%
#random float between 0 and 1
random.random()
# Out:
# 0.4324020802298759

# %%
#random int within an inclusive range 
random.randint(-10,10)
# Out:
# 1

# %%
# random int within an inclusive range including a step
random.randrange(-9,9,2)
# Out:
# -1

# %%
# random float within a range
random.uniform(-10.5,10.5)
# Out:
# -6.243902852507482

# %%
# You can also use the Numpy module
import numpy as np
np.random.uniform(10,12)
# Out:
# 10.418010924159338

# %%
# We can use the size parameter to generate a number of floating point decimals
np.random.uniform(10,50, size = 10)
# Out:
# array([37.45867773, 27.73095306, 44.23254566, 11.64966987, 28.31175911,
#        48.80396691, 47.40119149, 12.97082578, 16.34196666, 36.21836991])

# %%
# How much faster is using Numpy's random module than a while loop? lets add the %timeit magic command and see
import timeit
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 12.3 µs ± 108 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# when I first run the above sell, Numpys random module took about 12.2 microseconds to run. Lets test the while loop now.
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# When I first run this cell, it took the processor and RAM 1.52 milliseconds. A while loop proves to be 100x slower
# than Numpys random module.
# Out:
# 1.54 ms ± 14.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high =180.000, size = 1500)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# khandyga ru
# yellowknife ca
# kapaa us
# belushya guba ru
# beyneu kz
# naze jp
# ushuaia ar
# naze jp
# ushuaia ar
# ushuaia ar
# port alfred za
# atar mr
# nishihara jp
# pithora in
# ortona it
# nikolskoye ru
# torbay ca
# mata cn
# lagoa pt
# kharan pk
# datong cn
# bengkulu id
# zhigansk ru
# bluff nz
# hermanus za
# abbeville us
# mataura pf
# bredasdorp za
# puerto ayora ec
# atuona pf
# margate za
# dikson ru
# atuona pf
# punta arenas cl
# arraial do cabo br
# erenhot cn
# cherskiy ru
# albany au
# svetlogorsk ru
# ushuaia ar
# fortuna us
# lavrentiya ru
# illoqqortoormiut gl
# burica pa
# nuevo casas grandes mx
# taolanaro mg
# iqaluit ca
# taolanaro mg
# vaini to
# aberdeen us
# yellowknife ca
# grajau br
# moindou nc
# namatanai pg
# illoqqortoormiut gl
# punta arenas cl
# kapaa us
# rikitea pf
# cap malheureux mu
# chenzhou cn
# hobart au
# bredasdorp za
# bredasdorp za
# noumea nc
# kapaa us
# hobart au
# jamestown sh
# codrington ag
# nikolskoye ru
# paamiut gl
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 586

# %%
#import requests library
import requests

#import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=dbd212d2bf47b93a617ffb067e5056cd

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=dbd212d2bf47b93a617ffb067e5056cd&q=Boston

# %%
# Make a "Get" request for the city weather
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Adding a conditional that evaluate the status code may be helpful
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 73.53,
#   'feels_like': 63.19,
#   'temp_min': 71.01,
#   'temp_max': 75.99,
#   'pressure': 1009,
#   'humidity': 28},
#  'visibility': 10000,
#  'wind': {'speed': 13.87, 'deg': 290, 'gust': 21.92},
#  'clouds': {'all': 40},
#  'dt': 1598480441,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1598436226,
#   'sunset': 1598484508},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
# We use a key to get a corresponding value
boston_data['sys']
# Out:
# {'type': 1,
#  'id': 3486,
#  'country': 'US',
#  'sunrise': 1598436226,
#  'sunset': 1598484508}

# %%
# We can also use a subkey
boston_data['sys']["country"]
# Out:
# 'US'

# %%
# We can use similar syntax to get several weaather parameters
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.36 -71.06 75.99 28 40 13.87

# %%
boston_data["dt"]
# Out:
# 1598480441

# %%
# This is in UTC (Coordinated Universal Time) format, we'll need to import Pythons datetime module and library
# to convert the time stamp
from datetime import datetime
date = boston_data["dt"]
# The following line converts the UTC date to a date formatted by year, month, day, hour, minute and second
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 8, 26, 22, 20, 41)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-08-26 22:20:41'

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning data retrieval")
print("------------------------")
# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning data retrieval
# ------------------------
# Processing Record 1 of Set 1 | khandyga
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | beyneu
# Processing Record 6 of Set 1 | naze
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | nishihara
# Processing Record 11 of Set 1 | pithora
# Processing Record 12 of Set 1 | ortona
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | torbay
# Processing Record 15 of Set 1 | mata
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | kharan
# Processing Record 18 of Set 1 | datong
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | zhigansk
# Processing Record 21 of Set 1 | bluff
# ...

# %%
print(f"We have collected a data for a total of {len(city_data)} cities.")
# Out:
# We have collected a data for a total of 541 cities.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Khandyga  62.67  135.60     52.09        50           0        1.23
# 1  Yellowknife  62.46 -114.35     57.20        93          90        3.36
# 2        Kapaa  22.08 -159.32     86.00        66          40       11.41
# 3       Beyneu  45.32   55.20     72.64        24           0        5.91
# 4         Naze  28.37  129.48     80.60        88          75       28.86
# 5      Ushuaia -54.80  -68.30     41.00        56          75        3.51
# 6  Port Alfred -33.59   26.89     58.51        68          79       18.39
# 7         Atar  20.52  -13.05     97.38        32          30        3.20
# 8    Nishihara  26.18  127.76     82.40        94          75       10.29
# 9      Pithora  21.27   82.52     73.47        97         100       12.26
#
#   Country                 Date
# 0      RU  2020-08-26 22:31:33
# 1      CA  2020-08-26 22:31:03
# 2      US  2020-08-26 22:31:33
# ...

# %%
new_column_order = ["City", "Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Date"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Khandyga      RU  62.67  135.60     52.09        50           0
# 1     Yellowknife      CA  62.46 -114.35     57.20        93          90
# 2           Kapaa      US  22.08 -159.32     86.00        66          40
# 3          Beyneu      KZ  45.32   55.20     72.64        24           0
# 4            Naze      JP  28.37  129.48     80.60        88          75
# ..            ...     ...    ...     ...       ...       ...         ...
# 536     Katherine      AU -14.47  132.27     59.00        58          13
# 537  Port-Cartier      CA  50.03  -66.87     50.00        70          90
# 538      Vallenar      CL -28.57  -70.76     58.82        44           0
# 539   Walla Walla      US  46.06 -118.34     86.00        20           1
# 540        Magole      TZ  -6.37   37.37     71.60        88          75
#
#      Wind Speed                 Date
# 0          1.23  2020-08-26 22:31:33
# ...

# %%
# Lets create an output file to save the DataFrame as a csv in a new folder
output_data_file = "weather_data/cities.csv"
# Export the city_data dataframe into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
